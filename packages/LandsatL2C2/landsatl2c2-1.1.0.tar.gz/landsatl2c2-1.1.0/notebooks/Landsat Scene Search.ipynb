# %%
from LandsatL2C2 import LandsatL2C2
from sentinel_tiles import sentinel_tiles

# %%
landsat = LandsatL2C2()
landsat
# Out:
# {
#   "host": "https://m2m.cr.usgs.gov/api/api/json/stable/",
#   "key": "eyJjaWQiOjEyODE0NjAsInMiOiIxNzU4OTE1MDQ4IiwiciI6MTI3LCJwIjpbInVzZXIiXX0=",
#   "download_directory": "./landsat_download",
#   "products_directory": "./landsat_products",
#   "mosaic_directory": "./landsat_mosaic"
# }

# %%
geometry = sentinel_tiles.grid("11SPS", 30)
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
search_results = landsat.scene_search(
    start="2025-09-01",
    end="2025-09-30",
    target_geometry=geometry
)

search_results
# Out:
# [2025-09-26 12:35:47 INFO] Landsat path/row tiles: 038.037, 038.038, 039.037
# [2025-09-26 12:35:47 INFO] searching dataset landsat_etm_c2_l2 tile 038.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:47 INFO] searching dataset landsat_etm_c2_l2 tile 038.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:48 INFO] found 0 scenes
# [2025-09-26 12:35:48 INFO] searching dataset landsat_etm_c2_l2 tile 038.038 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:48 INFO] found 0 scenes
# [2025-09-26 12:35:48 INFO] searching dataset landsat_etm_c2_l2 tile 038.038 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:48 INFO] found 0 scenes
# [2025-09-26 12:35:48 INFO] searching dataset landsat_etm_c2_l2 tile 039.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:48 INFO] found 0 scenes
# [2025-09-26 12:35:48 INFO] searching dataset landsat_etm_c2_l2 tile 039.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:49 INFO] found 0 scenes
# [2025-09-26 12:35:49 INFO] searching dataset landsat_ot_c2_l2 tile 038.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:49 INFO] found 0 scenes
# [2025-09-26 12:35:49 INFO] searching dataset landsat_ot_c2_l2 tile 038.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:49 INFO] found 3 scenes
# [2025-09-26 12:35:49 INFO] searching dataset landsat_ot_c2_l2 tile 038.038 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:49 INFO] found 3 scenes
# [2025-09-26 12:35:49 INFO] searching dataset landsat_ot_c2_l2 tile 038.038 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:50 INFO] found 3 scenes
# [2025-09-26 12:35:50 INFO] searching dataset landsat_ot_c2_l2 tile 039.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:50 INFO] found 3 scenes
# [2025-09-26 12:35:50 INFO] searching dataset landsat_ot_c2_l2 tile 039.037 from 2025-09-01 to 2025-09-30
# [2025-09-26 12:35:50 INFO] found 2 scenes
#             dataset    date_UTC                                display_ID  \
# 0  landsat_ot_c2_l2  2025-09-05  LC08_L2SP_039037_20250905_20250912_02_T1
# 1  landsat_ot_c2_l2  2025-09-06  LC09_L2SP_038037_20250906_20250909_02_T1
# 1  landsat_ot_c2_l2  2025-09-06  LC09_L2SP_038038_20250906_20250909_02_T1
# 1  landsat_ot_c2_l2  2025-09-13  LC09_L2SP_039037_20250913_20250915_02_T1
# 0  landsat_ot_c2_l2  2025-09-14  LC08_L2SP_038037_20250914_20250920_02_T1
# 0  landsat_ot_c2_l2  2025-09-14  LC08_L2SP_038038_20250914_20250920_02_T1
# 2  landsat_ot_c2_l2  2025-09-22  LC09_L2SP_038037_20250922_20250923_02_T1
# 2  landsat_ot_c2_l2  2025-09-22  LC09_L2SP_038038_20250922_20250923_02_T1
#
#                entity_ID  cloud sensor    tile  \
# 0  LC80390372025248LGN00   20.0   LC08  039037
# 1  LC90380372025249LGN00    6.0   LC09  038037
# 1  LC90380382025249LGN00   12.0   LC09  038038
# 1  LC90390372025256LGN00    0.0   LC09  039037
# 0  LC80380372025257LGN00    0.0   LC08  038037
# 0  LC80380382025257LGN00    0.0   LC08  038038
# 2  LC90380372025265LGN00   55.0   LC09  038037
# 2  LC90380382025265LGN00   16.0   LC09  038038
#
#                                  granule_ID  \
# 0  LC08_L2SP_039037_20250905_20250912_02_T1
# 1  LC09_L2SP_038037_20250906_20250909_02_T1
# 1  LC09_L2SP_038038_20250906_20250909_02_T1
# 1  LC09_L2SP_039037_20250913_20250915_02_T1
# 0  LC08_L2SP_038037_20250914_20250920_02_T1
# 0  LC08_L2SP_038038_20250914_20250920_02_T1
# 2  LC09_L2SP_038037_20250922_20250923_02_T1
# 2  LC09_L2SP_038038_20250922_20250923_02_T1
#
#                                             geometry
# 0  POLYGON ((-116.83943 32.502, -114.8682 32.1139...
# 1  POLYGON ((-115.31404 32.50078, -113.34345 32.1...
# 1  POLYGON ((-115.68457 31.06464, -113.74202 30.6...
# 1  POLYGON ((-116.85663 32.50071, -114.88545 32.1...
# 0  POLYGON ((-115.29982 32.50205, -113.32916 32.1...
# 0  POLYGON ((-115.67048 31.0654, -113.72788 30.68...
# 2  POLYGON ((-115.31065 32.50092, -113.34002 32.1...
# 2  POLYGON ((-115.68114 31.06427, -113.73854 30.6...
