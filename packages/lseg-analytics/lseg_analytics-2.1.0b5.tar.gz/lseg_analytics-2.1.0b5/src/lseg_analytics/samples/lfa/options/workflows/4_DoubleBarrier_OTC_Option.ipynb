# %% [markdown]
# # Double Barrier OTC Options

# %% [markdown]
# This notebook demonstrates how to access and use the functinalities of **ETI Options** which are part of our **QPS** module within LSEG Financial Analytics SDK.

# %% [markdown]
# ## Imports

# %%
from lseg_analytics.instruments.options import (
    value,
    OptionDefinition,
    OptionDefinitionInstrument,
    OptionPricingParameters,
    UnderlyingDefinition,
    ExerciseDefinition,
    ScheduleDefinition,
    BarrierDefinition
)

from lseg_analytics.common import AdjustableDate
from datetime import date
import pandas as pd
import json as js

# %% [markdown]
# ## Pricing a Double Barrier OTC Option

# %%
definition = OptionDefinition(
    underlying = UnderlyingDefinition(
        code="AAPL.O",
        underlying_type="Equity"
    ),
    exercise = ExerciseDefinition(
        strike=240,
        exercise_style="European",
        schedule = ScheduleDefinition(
            end_date = AdjustableDate(
                date = date(2025, 8, 13)
            )
        )
    ),
    barrier_up= BarrierDefinition(
        barrier_mode="European",
        level=250,
        in_or_out="In"
    ),
    barrier_down= BarrierDefinition(
        barrier_mode="European",
        level=220,
        in_or_out="In"
    ),
    option_type="Call"
)

pricing_parameters=OptionPricingParameters(
    valuation_date=date(2024, 12, 18)
)

response = value(
    definitions=[OptionDefinitionInstrument(definition=definition)],
    pricing_preferences=pricing_parameters
)

print(js.dumps(response.as_dict(), indent=4))
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "underlying": {
#                     "underlyingType": "Equity",
#                     "code": "AAPL.O"
#                 },
#                 "exercise": {
#                     "strike": 240.0,
#                     "schedule": {
#                         "endDate": {
#                             "dateType": "AdjustableDate",
#                             "date": "2025-08-13"
#                         }
#                     },
#                     "exerciseStyle": "European"
#                 },
#                 "optionType": "Call",
#                 "barrierUp": {
#                     "barrierMode": "European",
#                     "inOrOut": "In",
#                     "level": 250.0
#                 },
#                 "barrierDown": {
#                     "barrierMode": "European",
#                     "inOrOut": "In",
#                     "level": 220.0
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "valuationDate": "2024-12-18"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "instrumentCode": "",
#                 "underlyingRic": "AAPL.O",
#                 "instrumentDescription": "Barrier_EURO_AAPL.O"
#             },
#             "valuation": {
#                 "volatility": {
#                     "value": 24.1185876002151,
#                     "unit": "Percentage"
#                 },
#                 "marketValue": {
#                     "value": 3.59357172209351,
#                     "dealCurrency": {
#                         "value": 3.59357172209351,
#                         "currency": "USD"
#                     }
#                 },
#                 "totalMarketValue": {
#                     "value": 3.59357172209351,
#                     "dealCurrency": {
#                         "value": 3.59357172209351,
#                         "currency": "USD"
#                     }
#                 },
#                 "intrinsicValue": {
#                     "value": 8.05000000000001,
#                     "dealCurrency": {
#                         "value": 8.05000000000001,
#                         "currency": "USD"
#                     }
#                 },
#                 "timeValue": {
#                     "value": -4.4564282779065,
#                     "dealCurrency": {
#                         "value": -4.4564282779065,
#                         "currency": "USD"
#                     }
#                 },
#                 "premiumOverCash": {
#                     "value": -0.0179658467160109,
#                     "percent": -1.79658467160109,
#                     "dealCurrency": {
#                         "value": -4.4564282779065,
#                         "currency": "USD"
#                     }
#                 },
#                 "moneyness": {
#                     "value": 103.354166666667,
#                     "unit": "Percentage"
#                 },
#                 "annualizedYield": {
#                     "value": -0.0274373809679664,
#                     "unit": "Absolute"
#                 }
#             },
#             "risk": {
#                 "hedgeRatio": 6.88294389159282,
#                 "leverage": -10.0285624886764,
#                 "delta": {
#                     "value": -0.145286670318706,
#                     "percent": -14.5286670318706,
#                     "dealCurrency": {
#                         "value": -0.145286670318706,
#                         "currency": "USD"
#                     }
#                 },
#                 "gamma": {
#                     "value": 0.00541808764500897,
#                     "percent": 0.541808764500897,
#                     "dealCurrency": {
#                         "value": 0.00541808764500897,
#                         "currency": "USD"
#                     }
#                 },
#                 "rho": {
#                     "value": 0.0710338720036872,
#                     "percent": 7.10338720036872,
#                     "dealCurrency": {
#                         "value": 0.0710338720036872,
#                         "currency": "USD"
#                     }
#                 },
#                 "theta": {
#                     "value": -0.0238963017954923,
#                     "percent": -2.38963017954923,
#                     "dealCurrency": {
#                         "value": -0.0238963017954923,
#                         "currency": "USD"
#                     }
#                 },
#                 "vega": {
#                     "value": 0.457671413742892,
#                     "percent": 45.7671413742892,
#                     "dealCurrency": {
#                         "value": 0.457671413742892,
#                         "currency": "USD"
#                     }
#                 }
#             }
#         }
#     ]
# }

# %%
valuation = response.analytics[0].valuation

import pandas as pd

def flatten(data):
    rows = []

    for key, section in data.items():
        row = {"metric": key}

        # Start with raw values
        value = section.get("value")
        unit = section.get("unit")
        percent = section.get("percent")

        # Handle dealCurrency override
        dc = section.get("dealCurrency")
        if dc is not None:
            value = getattr(dc, "value", value)
            unit = getattr(dc, "currency", unit)

        # Round and assign
        if value is not None:
            row["value"] = round(value, 3)
        if unit is not None:
            row["unit"] = unit
        if percent is not None:
            row["percent"] = round(percent, 3)

        rows.append(row)

    return pd.DataFrame(rows).set_index("metric")

flatten(valuation)
# Out:
#                     value        unit  percent
# metric
# volatility         24.119  Percentage      NaN
# marketValue         3.594         USD      NaN
# totalMarketValue    3.594         USD      NaN
# intrinsicValue      8.050         USD      NaN
# timeValue          -4.456         USD      NaN
# premiumOverCash    -4.456         USD   -1.797
# moneyness         103.354  Percentage      NaN
# annualizedYield    -0.027    Absolute      NaN
