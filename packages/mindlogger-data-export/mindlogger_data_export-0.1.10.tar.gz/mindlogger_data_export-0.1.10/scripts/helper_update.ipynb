# %% [markdown]
# # YMHA Data Processing Workflow
#
# This notebook processes attendance and completion files, highlights TRUE (green) and FALSE (red), creates a 'complete' column, and organizes files by date and site. By default, it processes all dates, but you can configure it to process only one date.

# %%
import os
import re
import shutil
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

# %%
def process_attendance_files(folder_path, output_folder):
    """Highlight TRUE (green) and FALSE (red) in attendance files, save to output_folder/date/filename."""
    pattern = re.compile(
        r"ymha_attendance-site_(.+)-date_(2025-\d{2}-\d{2})\.xlsx$", re.IGNORECASE
    )
    red_fill = PatternFill(start_color="F4CCCC", end_color="F4CCCC", fill_type="solid")
    green_fill = PatternFill(
        start_color="D9EAD3", end_color="D9EAD3", fill_type="solid"
    )
    all_files = os.listdir(folder_path)
    files_of_interest = [fname for fname in all_files if pattern.search(fname)]
    for filename in files_of_interest:
        match = pattern.search(filename)
        if match:
            date_str = match.group(2)
            file_path = os.path.join(folder_path, filename)
            try:
                wb = load_workbook(file_path)
                ws = wb.active
                header = [
                    cell.value for cell in next(ws.iter_rows(min_row=1, max_row=1))
                ]
                try:
                    checkin_idx = header.index("Student Check-Ins") + 1
                    checkout_idx = header.index("Student Check-Outs") + 1
                except ValueError:
                    print(f"Columns not found in {filename}")
                    continue
                for row in ws.iter_rows(min_row=2, max_row=ws.max_row):
                    for idx in [checkin_idx, checkout_idx]:
                        val = str(row[idx - 1].value).strip().upper()
                        if val == "FALSE":
                            row[idx - 1].fill = red_fill
                        elif val == "TRUE":
                            row[idx - 1].fill = green_fill
                date_folder = os.path.join(output_folder, date_str)
                os.makedirs(date_folder, exist_ok=True)
                new_path = os.path.join(date_folder, filename)
                wb.save(new_path)
            except Exception as e:
                print(f"Error processing {filename}: {e}")

# %%
def process_completion_files(folder_path, output_folder):
    """Create 'complete' column in completion files, highlight as needed, save to output_folder/complete/filename."""
    import openpyxl

    assessment_columns = [
        "AMHLQ",
        "Healthcare Access",
        "Impact and Professional Importance",
        "MAP + MH Interest",
        "MEIM-6",
        "Mental Health Attitudes and Help-Seeking",
        "Mental Healthcare",
        "PCRB",
        "PEARLS + CRISIS",
        "PSC",
        "SCCS",
        "SCCT",
        "SEHS-HE",
        "Student Week 1 Assessment",
    ]
    red_fill = PatternFill(start_color="F4CCCC", end_color="F4CCCC", fill_type="solid")
    yellow_fill = PatternFill(
        start_color="FFF2CC", end_color="FFF2CC", fill_type="solid"
    )
    green_fill = PatternFill(
        start_color="D9EAD3", end_color="D9EAD3", fill_type="solid"
    )
    complete_folder = os.path.join(output_folder, "complete")
    os.makedirs(complete_folder, exist_ok=True)
    files = os.listdir(folder_path)
    for file in files:
        if file.startswith("ymha_completion-site_") and file.endswith(".xlsx"):
            file_path = os.path.join(folder_path, file)
            wb = openpyxl.load_workbook(file_path)
            ws = wb.active
            header = [cell.value for cell in next(ws.iter_rows(min_row=1, max_row=1))]
            # Remove last two columns if they match
            for _ in range(2):
                if header and header[-1] in ["Student Week 2 Assessment", "complete"]:
                    ws.delete_cols(len(header))
                    header.pop()
            ws.cell(row=1, column=len(header) + 1, value="complete")
            header.append("complete")
            col_indices = [
                header.index(col) + 1 for col in assessment_columns if col in header
            ]
            complete_col_idx = len(header)
            for row in ws.iter_rows(min_row=2, max_row=ws.max_row):
                values = []
                for idx in col_indices:
                    val = str(row[idx - 1].value).strip().upper()
                    values.append(val == "TRUE")
                if all(values) and values:
                    result = "TRUE"
                elif not any(values):
                    result = "FALSE"
                else:
                    result = "PARTIALLY TRUE"
                ws.cell(row=row[0].row, column=complete_col_idx, value=result)
                if result == "FALSE":
                    ws.cell(row=row[0].row, column=complete_col_idx).fill = red_fill
                elif result == "PARTIALLY TRUE":
                    ws.cell(row=row[0].row, column=complete_col_idx).fill = yellow_fill
                elif result == "TRUE":
                    ws.cell(row=row[0].row, column=complete_col_idx).fill = green_fill
            new_path = os.path.join(complete_folder, file)
            wb.save(new_path)

# %%
def find_all_attendance_dates(folder_path):
    """Recursively find all unique attendance dates in folder_path and its subfolders."""
    attendance_pattern = re.compile(
        r"ymha_attendance-site_(.+)-date_(2025-\d{2}-\d{2})\.xlsx$", re.IGNORECASE
    )
    all_dates = set()
    for root, dirs, files in os.walk(folder_path):
        for fname in files:
            match = attendance_pattern.match(fname)
            if match:
                all_dates.add(match.group(2))
    return all_dates

# %%
def organize_site_files_by_date(site_name=None, date_str=None, folder_path=None):
    """
    Organize all attendance and completion files for a given date into subfolders by site.
    For each site with an attendance file for the given date:
        - Create a subfolder under the date folder named after the site.
        - Copy the attendance file and the corresponding completion file into the site subfolder.
    If site_name is provided, only process that site for the given date.
    """
    if folder_path is None or date_str is None:
        print("folder_path and date_str are required.")
        return
    pattern = re.compile(r"ymha_attendance-site_(.+)-date_{}\.xlsx".format(date_str))
    attendance_folder = os.path.join(folder_path, date_str)
    complete_folder = os.path.join(folder_path, "complete")
    files = []
    for root, dirs, fs in os.walk(attendance_folder):
        files.extend(fs)
    if site_name:
        site_names = [site_name]
    else:
        site_names = [pattern.match(f).group(1) for f in files if pattern.match(f)]
    for site in site_names:
        attendance_file = f"ymha_attendance-site_{site}-date_{date_str}.xlsx"
        completion_file = f"ymha_completion-site_{site}.xlsx"
        site_folder = os.path.join(attendance_folder, site)
        os.makedirs(site_folder, exist_ok=True)
        att_src = os.path.join(attendance_folder, attendance_file)
        att_dst = os.path.join(site_folder, attendance_file)
        if os.path.exists(att_src):
            shutil.copy2(att_src, att_dst)
            print(f"Copied {attendance_file} to {site_folder}")
        else:
            print(f"Attendance file not found: {att_src}")
        comp_src = os.path.join(complete_folder, completion_file)
        comp_dst = os.path.join(site_folder, completion_file)
        if os.path.exists(comp_src):
            shutil.copy2(comp_src, comp_dst)
            print(f"Copied {completion_file} to {site_folder}")
        else:
            print(f"Completion file not found: {comp_src}")

# %%
# Set your folder path here
folder_path = "/Users/yanyi.wang/Desktop/ymha/output_7_8"  # Change as needed
# Set to a date string like "2025-07-03" to process only one date, or None for all
date_to_process = None  # e.g., "2025-07-03" or None

# Step 1: Process attendance files and save to attendance folders by date
process_attendance_files(folder_path, folder_path)
# Step 2: Process completion files and save to complete folder
process_completion_files(folder_path, folder_path)
# Step 3: Organize by site/date
if date_to_process:
    organize_site_files_by_date(date_str=date_to_process, folder_path=folder_path)
else:
    all_dates = find_all_attendance_dates(folder_path)
    for date_str in all_dates:
        organize_site_files_by_date(date_str=date_str, folder_path=folder_path)
# Out:
# Copied ymha_attendance-site_Pierce-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/uc_riverside
# Copied ymha_attendance-site_west_la-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/west_la
# Copied ymha_attendance-site_palomar-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/palomar
# Copied ymha_attendance-site_ohlone-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/ohlone
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/manuel_dominguez
# Copied ymha_attendance-site_san_diego_city-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/san_diego_city
# Copied ymha_attendance-site_grossmont-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/grossmont
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/cal_sacramento
# Copied ymha_attendance-site_orange coast-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/azusa_pacific
# Copied ymha_attendance-site_el_camino-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/el_camino
# Copied ymha_attendance-site_long_beach_city-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/long_beach_city
# Copied ymha_attendance-site_chabot-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/chabot
# Copied ymha_attendance-site_college_track-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/college_track
# Copied ymha_attendance-site_cal_state_la-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/contra_costa
# Copied ymha_attendance-site_laney-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/laney
# Copied ymha_attendance-site_compton-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/compton
# Copied ymha_attendance-site_redlands-date_2025-06-28.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-28/redlands
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/cal_sacramento
# Copied ymha_attendance-site_grossmont-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/manuel_dominguez
# Copied ymha_attendance-site_ohlone-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/ohlone
# Copied ymha_attendance-site_palomar-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/palomar
# Copied ymha_attendance-site_west_la-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/west_la
# Copied ymha_attendance-site_uc_riverside-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/uc_riverside
# Copied ymha_attendance-site_Pierce-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/Pierce
# Copied ymha_attendance-site_redlands-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/redlands
# Copied ymha_attendance-site_compton-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/compton
# Copied ymha_attendance-site_laney-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/laney
# Copied ymha_attendance-site_contra_costa-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/contra_costa
# Copied ymha_attendance-site_cal_state_la-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/cal_state_la
# Copied ymha_attendance-site_college_track-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/college_track
# Copied ymha_attendance-site_chabot-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/long_beach_city
# Copied ymha_attendance-site_el_camino-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-23.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-23/azusa_pacific
# Copied ymha_attendance-site_palomar-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/palomar
# Copied ymha_attendance-site_west_la-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/west_la
# Copied ymha_attendance-site_Pierce-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/uc_riverside
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/cal_sacramento
# Copied ymha_attendance-site_ohlone-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/manuel_dominguez
# Copied ymha_attendance-site_chabot-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/long_beach_city
# Copied ymha_attendance-site_college_track-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/college_track
# Copied ymha_attendance-site_el_camino-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/el_camino
# Copied ymha_attendance-site_azusa_pacific-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/azusa_pacific
# Copied ymha_attendance-site_orange coast-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/orange coast
# Copied ymha_attendance-site_laney-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/laney
# Copied ymha_attendance-site_redlands-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/redlands
# Copied ymha_attendance-site_compton-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/compton
# Copied ymha_attendance-site_cal_state_la-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-07-08.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-08/contra_costa
# Copied ymha_attendance-site_contra_costa-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/contra_costa
# Copied ymha_attendance-site_cal_state_la-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/cal_state_la
# Copied ymha_attendance-site_redlands-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/redlands
# Copied ymha_attendance-site_compton-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/compton
# Copied ymha_attendance-site_laney-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/laney
# Copied ymha_attendance-site_el_camino-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/azusa_pacific
# Copied ymha_attendance-site_college_track-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/college_track
# Copied ymha_attendance-site_long_beach_city-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/long_beach_city
# Copied ymha_attendance-site_chabot-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/chabot
# Copied ymha_attendance-site_grossmont-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/grossmont
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/manuel_dominguez
# Copied ymha_attendance-site_san_diego_city-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/san_diego_city
# Copied ymha_attendance-site_ohlone-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/ohlone
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/cal_sacramento
# Copied ymha_attendance-site_uc_riverside-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/uc_riverside
# Copied ymha_attendance-site_Pierce-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/Pierce
# Copied ymha_attendance-site_west_la-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/west_la
# Copied ymha_attendance-site_palomar-date_2025-06-30.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-30/palomar
# Copied ymha_attendance-site_cal_state_la-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/contra_costa
# Copied ymha_attendance-site_laney-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/laney
# Copied ymha_attendance-site_redlands-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/redlands
# Copied ymha_attendance-site_compton-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/compton
# Copied ymha_attendance-site_el_camino-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/azusa_pacific
# Copied ymha_attendance-site_chabot-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/long_beach_city
# Copied ymha_attendance-site_college_track-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/college_track
# Copied ymha_attendance-site_ohlone-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/manuel_dominguez
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/cal_sacramento
# Copied ymha_attendance-site_Pierce-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/uc_riverside
# Copied ymha_attendance-site_palomar-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/palomar
# Copied ymha_attendance-site_west_la-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/west_la
# Copied ymha_attendance-site_long_beach_city-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/long_beach_city
# Copied ymha_attendance-site_chabot-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/chabot
# Copied ymha_attendance-site_college_track-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/college_track
# Copied ymha_attendance-site_el_camino-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/azusa_pacific
# Copied ymha_attendance-site_laney-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/laney
# Copied ymha_attendance-site_redlands-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/redlands
# Copied ymha_attendance-site_compton-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/compton
# Copied ymha_attendance-site_cal_state_la-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/contra_costa
# Copied ymha_attendance-site_palomar-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/palomar
# Copied ymha_attendance-site_west_la-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/west_la
# Copied ymha_attendance-site_Pierce-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/uc_riverside
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/cal_sacramento
# Copied ymha_attendance-site_ohlone-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/manuel_dominguez
# Copied ymha_attendance-site_palomar-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/palomar
# Copied ymha_attendance-site_west_la-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/west_la
# Copied ymha_attendance-site_uc_riverside-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/uc_riverside
# Copied ymha_attendance-site_Pierce-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/Pierce
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/cal_sacramento
# Copied ymha_attendance-site_grossmont-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/manuel_dominguez
# Copied ymha_attendance-site_ohlone-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/ohlone
# Copied ymha_attendance-site_college_track-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/college_track
# Copied ymha_attendance-site_chabot-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/long_beach_city
# Copied ymha_attendance-site_el_camino-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/azusa_pacific
# Copied ymha_attendance-site_redlands-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/redlands
# Copied ymha_attendance-site_compton-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/compton
# Copied ymha_attendance-site_laney-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/laney
# Copied ymha_attendance-site_contra_costa-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/contra_costa
# Copied ymha_attendance-site_cal_state_la-date_2025-07-04.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-04/cal_state_la
# Copied ymha_attendance-site_college_track-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/college_track
# Copied ymha_attendance-site_long_beach_city-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/long_beach_city
# Copied ymha_attendance-site_chabot-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/chabot
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/azusa_pacific
# Copied ymha_attendance-site_orange coast-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/orange coast
# Copied ymha_attendance-site_el_camino-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/el_camino
# Copied ymha_attendance-site_compton-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/compton
# Copied ymha_attendance-site_redlands-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/redlands
# Copied ymha_attendance-site_laney-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/laney
# Copied ymha_attendance-site_contra_costa-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/contra_costa
# Copied ymha_attendance-site_cal_state_la-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/cal_state_la
# Copied ymha_attendance-site_west_la-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/west_la
# Copied ymha_attendance-site_palomar-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/palomar
# Copied ymha_attendance-site_uc_riverside-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/uc_riverside
# Copied ymha_attendance-site_Pierce-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/Pierce
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/cal_sacramento
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/manuel_dominguez
# Copied ymha_attendance-site_san_diego_city-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/san_diego_city
# Copied ymha_attendance-site_grossmont-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/grossmont
# Copied ymha_attendance-site_ohlone-date_2025-06-21.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-21/ohlone
# Copied ymha_attendance-site_el_camino-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/azusa_pacific
# Copied ymha_attendance-site_college_track-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/college_track
# Copied ymha_attendance-site_chabot-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/long_beach_city
# Copied ymha_attendance-site_contra_costa-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/contra_costa
# Copied ymha_attendance-site_cal_state_la-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/cal_state_la
# Copied ymha_attendance-site_redlands-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/redlands
# Copied ymha_attendance-site_compton-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/compton
# Copied ymha_attendance-site_laney-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/laney
# Copied ymha_attendance-site_uc_riverside-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/uc_riverside
# Copied ymha_attendance-site_Pierce-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/Pierce
# Copied ymha_attendance-site_palomar-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/palomar
# Copied ymha_attendance-site_west_la-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/west_la
# Copied ymha_attendance-site_grossmont-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/manuel_dominguez
# Copied ymha_attendance-site_ohlone-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/ohlone
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-01.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-01/cal_sacramento
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/manuel_dominguez
# Copied ymha_attendance-site_san_diego_city-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/san_diego_city
# Copied ymha_attendance-site_grossmont-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/grossmont
# Copied ymha_attendance-site_ohlone-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/ohlone
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/cal_sacramento
# Copied ymha_attendance-site_uc_riverside-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/uc_riverside
# Copied ymha_attendance-site_Pierce-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/Pierce
# Copied ymha_attendance-site_west_la-date_2025-07-03.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-03/west_la
# Copied ymha_attendance-site_long_beach_city-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/long_beach_city
# Copied ymha_attendance-site_college_track-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/college_track
# Copied ymha_attendance-site_ohlone-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/manuel_dominguez
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/cal_sacramento
# Copied ymha_attendance-site_Pierce-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/uc_riverside
# Copied ymha_attendance-site_palomar-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/palomar
# Copied ymha_attendance-site_west_la-date_2025-07-07.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-07/west_la
# Copied ymha_attendance-site_long_beach_city-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/long_beach_city
# Copied ymha_attendance-site_chabot-date_2025-06-17.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-17/chabot
# ...
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/manuel_dominguez
# Copied ymha_attendance-site_san_diego_city-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/san_diego_city
# Copied ymha_attendance-site_grossmont-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/grossmont
# Copied ymha_attendance-site_west_la-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/west_la
# Copied ymha_attendance-site_palomar-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/palomar
# Copied ymha_attendance-site_Pierce-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-06-27.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-27/uc_riverside
# Copied ymha_attendance-site_palomar-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/palomar
# Copied ymha_attendance-site_west_la-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/west_la
# Copied ymha_attendance-site_Pierce-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/uc_riverside
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/cal_sacramento
# Copied ymha_attendance-site_ohlone-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/manuel_dominguez
# Copied ymha_attendance-site_chabot-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/long_beach_city
# Copied ymha_attendance-site_college_track-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/college_track
# Copied ymha_attendance-site_el_camino-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/azusa_pacific
# Copied ymha_attendance-site_laney-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/laney
# Copied ymha_attendance-site_redlands-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/redlands
# Copied ymha_attendance-site_compton-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/compton
# Copied ymha_attendance-site_cal_state_la-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-06-25.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-25/contra_costa
# Copied ymha_attendance-site_el_camino-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/azusa_pacific
# Copied ymha_attendance-site_chabot-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/long_beach_city
# Copied ymha_attendance-site_college_track-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/college_track
# Copied ymha_attendance-site_cal_state_la-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/contra_costa
# Copied ymha_attendance-site_laney-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/laney
# Copied ymha_attendance-site_redlands-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/redlands
# Copied ymha_attendance-site_compton-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/compton
# Copied ymha_attendance-site_Pierce-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/uc_riverside
# Copied ymha_attendance-site_palomar-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/palomar
# Copied ymha_attendance-site_west_la-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/west_la
# Copied ymha_attendance-site_ohlone-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/manuel_dominguez
# Copied ymha_attendance-site_cal_sacramento-date_2025-06-20.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-06-20/cal_sacramento
# Copied ymha_attendance-site_cal_sacramento-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/cal_sacramento
# Copied ymha_completion-site_cal_sacramento.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/cal_sacramento
# Copied ymha_attendance-site_ohlone-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/ohlone
# Copied ymha_completion-site_ohlone.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/ohlone
# Copied ymha_attendance-site_grossmont-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/grossmont
# Copied ymha_completion-site_grossmont.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/grossmont
# Copied ymha_attendance-site_san_diego_city-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/san_diego_city
# Copied ymha_completion-site_san_diego_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/san_diego_city
# Copied ymha_attendance-site_manuel_dominguez-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/manuel_dominguez
# Copied ymha_completion-site_manuel_dominguez.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/manuel_dominguez
# Copied ymha_attendance-site_palomar-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/palomar
# Copied ymha_completion-site_palomar.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/palomar
# Copied ymha_attendance-site_west_la-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/west_la
# Copied ymha_completion-site_west_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/west_la
# Copied ymha_attendance-site_Pierce-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/Pierce
# Copied ymha_completion-site_Pierce.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/Pierce
# Copied ymha_attendance-site_uc_riverside-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/uc_riverside
# Copied ymha_completion-site_uc_riverside.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/uc_riverside
# Copied ymha_attendance-site_laney-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/laney
# Copied ymha_completion-site_laney.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/laney
# Copied ymha_attendance-site_redlands-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/redlands
# Copied ymha_completion-site_redlands.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/redlands
# Copied ymha_attendance-site_compton-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/compton
# Copied ymha_completion-site_compton.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/compton
# Copied ymha_attendance-site_cal_state_la-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/cal_state_la
# Copied ymha_completion-site_cal_state_la.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/cal_state_la
# Copied ymha_attendance-site_contra_costa-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/contra_costa
# Copied ymha_completion-site_contra_costa.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/contra_costa
# Copied ymha_attendance-site_chabot-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/chabot
# Copied ymha_completion-site_chabot.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/chabot
# Copied ymha_attendance-site_long_beach_city-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/long_beach_city
# Copied ymha_completion-site_long_beach_city.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/long_beach_city
# Copied ymha_attendance-site_college_track-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/college_track
# Copied ymha_completion-site_college_track.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/college_track
# Copied ymha_attendance-site_el_camino-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/el_camino
# Copied ymha_completion-site_el_camino.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/el_camino
# Copied ymha_attendance-site_orange coast-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/orange coast
# Copied ymha_completion-site_orange coast.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/orange coast
# Copied ymha_attendance-site_azusa_pacific-date_2025-07-02.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/azusa_pacific
# Copied ymha_completion-site_azusa_pacific.xlsx to /Users/yanyi.wang/Desktop/ymha/output_7_8/2025-07-02/azusa_pacific
