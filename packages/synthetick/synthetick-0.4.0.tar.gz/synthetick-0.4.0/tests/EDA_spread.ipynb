# %%
import matplotlib.pyplot as plt

import sys
sys.path.append("../")

# %%
from synthetick.Synthetick import Spread

# %%
spread = Spread(-4)

# %%
spread.produce(0.5, 3, 5000)

# %%
fig, ax = plt.subplots(1, figsize=(10,3))
plt_obj = plt.hist(spread.spread_raw, bins=100)
